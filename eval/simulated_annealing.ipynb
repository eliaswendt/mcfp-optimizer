# %%
import pandas as pd

# %%
df = pd.read_csv("simulated_annealing.csv")
df.plot(x='time', logy=True)
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df = pd.read_csv("simulated_annealing.csv")
df.plot(x='time', logy=True)
# Out:
# <AxesSubplot:xlabel='time'>
