# %%
import pandas as pd

# %%
df = pd.read_csv("simulated_annealing_best.csv")
df.plot(y=['cost', 'delay_cost', 'edge_cost'], x='time')
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df = pd.read_csv("simulated_annealing_cost.csv")
df.plot(y=['cost', 'delay_cost', 'edge_cost'], x='time')
df.plot(y=['temperature'], x='time', logy=True)
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df = pd.read_csv("simulated_annealing.csv")
df.plot(y=['cost', 'delay_cost'], x='time', logy=True)
df.plot(y=['edge_cost'], x='time', logy=True)
# Out:
# <AxesSubplot:xlabel='time'>
