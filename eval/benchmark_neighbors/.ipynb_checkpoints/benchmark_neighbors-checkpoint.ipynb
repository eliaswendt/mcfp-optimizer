# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("all_group_neighbors_iteration_0.csv", index_col=['group_index', 'path_index'])
initial_state = df.iloc[0]
neighbors = df.iloc[1:]

plt.figure(figsize=(10, 9))
neighbors.boxplot(column=['combined_cost'], by='group_index', figsize=(16,9))
# Out:
# <AxesSubplot:title={'center':'combined_cost'}, xlabel='group_index'>

# %%
df = pd.read_csv("all_direct_group_neighbors_iteration_0.csv", index_col=['group_index', 'path_index'])
initial_state = df.iloc[0]
neighbors = df.iloc[1:]

plt.figure(figsize=(10, 9))
neighbors.boxplot(column=['combined_cost'], by='group_index', figsize=(16,9))
#df.loc['group_index', :]
#df.loc['group_index']
#df.sort_index(inplace=True)
#df.unstack(level=0)
# Out:
# <AxesSubplot:title={'center':'combined_cost'}, xlabel='group_index'>
